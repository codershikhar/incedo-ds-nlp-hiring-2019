# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('train_file.csv')

# %%
df.head()
# Out:
#    Patient_ID  YEAR       LocationDesc  Subtopic  \
# 0           1  1995        Houston, TX         1
# 1           2  1997        Houston, TX         0
# 2           3  1993             Nevada         0
# 3           4  2017       Pennsylvania         1
# 4           5  2007  San Francisco, CA         1
#
#                                Greater_Risk_Question  \
# 0                                  Ever used cocaine
# 1                            Currently drank alcohol
# 2  Had their first drink of alcohol before age 13...
# 3                                  Ever used cocaine
# 4  Ever took steroids without a doctor's prescrip...
#
#                                          Description  Sample_Size     Sex  \
# 0  any form of cocaine, such as powder, crack, or...        335.0  Female
# 1  at least one drink of alcohol, on at least 1 d...        382.0   Total
# 2                              other than a few sips        196.0  Female
# 3  any form of cocaine, such as powder, crack, or...        104.0    Male
# 4  pills or shots, one or more times during their...        100.0  Female
#
#                         Race  Grade  \
# 0         Hispanic or Latino      4
# 1  Black or African American      4
# 2                      White      0
# 3                      Asian      4
# 4              Multiple Race      4
#
#                                  GeoLocation QuestionCode  StratID1  StratID2  \
# 0                    (29.760427, -95.369803)          H49         1         4
# 1                    (29.760427, -95.369803)          H42         0         3
# 2  (39.493240390000494, -117.07184056399967)          H41         1         6
# 3    (40.79373015200048, -77.86070029399963)          H49         2         2
# 4                    (37.77493, -122.419416)          H55         1         7
#
#    StratID3 StratificationType  Greater_Risk_Probability
# 0         0              Local                    7.4793
# 1         0              Local                   49.6852
# 2         2              State                   47.8132
# 3         0              State                    3.4554
# 4         0              Local                    0.0000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55399 entries, 0 to 55398
# Data columns (total 17 columns):
# Patient_ID                  55399 non-null int64
# YEAR                        55399 non-null int64
# LocationDesc                55399 non-null object
# Subtopic                    55399 non-null int64
# Greater_Risk_Question       55399 non-null object
# Description                 55399 non-null object
# Sample_Size                 55399 non-null float64
# Sex                         55399 non-null object
# Race                        55399 non-null object
# Grade                       55399 non-null int64
# GeoLocation                 52098 non-null object
# QuestionCode                55399 non-null object
# StratID1                    55399 non-null int64
# StratID2                    55399 non-null int64
# StratID3                    55399 non-null int64
# StratificationType          55399 non-null object
# Greater_Risk_Probability    55399 non-null float64
# dtypes: float64(2), int64(7), object(8)
# memory usage: 7.2+ MB

# %%
df.drop(columns=['GeoLocation'], inplace=True)

# %%
df.describe(include='all')
# Out:
#           Patient_ID          YEAR   LocationDesc      Subtopic  \
# count   55399.000000  55399.000000          55399  55399.000000
# unique           NaN           NaN             91           NaN
# top              NaN           NaN  United States           NaN
# freq             NaN           NaN           2276           NaN
# mean    27700.000000   2007.674308            NaN      0.747270
# std     15992.458118      6.906621            NaN      0.434581
# min         1.000000   1991.000000            NaN      0.000000
# 25%     13850.500000   2003.000000            NaN      0.000000
# 50%     27700.000000   2009.000000            NaN      1.000000
# 75%     41549.500000   2013.000000            NaN      1.000000
# max     55399.000000   2017.000000            NaN      1.000000
#
#            Greater_Risk_Question  \
# count                      55399
# unique                        20
# top     Currently used marijuana
# freq                        4421
# mean                         NaN
# std                          NaN
# min                          NaN
# 25%                          NaN
# 50%                          NaN
# 75%                          NaN
# max                          NaN
#
#                                               Description   Sample_Size  \
# count                                               55399  55399.000000
# unique                                                 20           NaN
# top     also called grass, pot, or weed, one or more t...           NaN
# freq                                                 4421           NaN
# mean                                                  NaN    566.206339
# std                                                   NaN   1148.727489
# min                                                   NaN     50.000000
# 25%                                                   NaN    165.000000
# 50%                                                   NaN    275.000000
# 75%                                                   NaN    560.500000
# max                                                   NaN  53664.000000
#
#           Sex   Race         Grade QuestionCode      StratID1      StratID2  \
# count   55399  55399  55399.000000        55399  55399.000000  55399.000000
# unique      3      8           NaN           20           NaN           NaN
# top     Total  Total           NaN          H48           NaN           NaN
# freq    22057  22252           NaN         4421           NaN           NaN
# mean      NaN    NaN      2.238488          NaN      0.897327      2.718479
# std       NaN    NaN      1.494005          NaN      0.826494      2.516150
# min       NaN    NaN      0.000000          NaN      0.000000      0.000000
# 25%       NaN    NaN      1.000000          NaN      0.000000      0.000000
# 50%       NaN    NaN      2.000000          NaN      1.000000      3.000000
# 75%       NaN    NaN      4.000000          NaN      2.000000      6.000000
# max       NaN    NaN      4.000000          NaN      2.000000      7.000000
#
#             StratID3 StratificationType  Greater_Risk_Probability
# count   55399.000000              55399              55399.000000
# unique           NaN                  5                       NaN
# top              NaN              State                       NaN
# freq             NaN              31878                       NaN
# mean        1.708695                NaN                 24.365664
# std         1.448596                NaN                 20.492551
# min         0.000000                NaN                  0.000000
# 25%         0.000000                NaN                  8.280050
# 50%         2.000000                NaN                 17.555600
# 75%         3.000000                NaN                 35.430750
# max         4.000000                NaN                 99.449400

# %%
Greater_Risk_Question = df.Greater_Risk_Question.unique()
Greater_Risk_Question
# Out:
# array(['Ever used cocaine', 'Currently drank alcohol',
#        'Had their first drink of alcohol before age 13 years',
#        "Ever took steroids without a doctor's prescription",
#        'Ever used inhalants',
#        'Were offered, sold, or given an illegal drug on school property',
#        'Ever used marijuana', 'Ever used heroin', 'Ever drank alcohol',
#        'Currently used marijuana', 'Ever used synthetic marijuana',
#        'Tried marijuana for the first time before age 13 years',
#        'Ever used methamphetamines', 'Ever injected any illegal drug',
#        'Ever used ecstasy',
#        'Reported 10 or more as the largest number of drinks they had in a row',
#        'Usually got the alcohol they drank by someone giving it to them',
#        "Ever took prescription pain medicine without a doctor's prescription or differently than how a doctor told them to use it",
#        'Ever used hallucinogenic drugs',
#        'Reported current binge drinking'], dtype=object)

# %%
for i in Greater_Risk_Question:
    print(len(df.loc[df.Greater_Risk_Question == i, 'Description'].unique()))
    print(i)
    print(df.loc[df.Greater_Risk_Question == i, 'Description'].unique())
# Out:
# 1
# Ever used cocaine
# ['any form of cocaine, such as powder, crack, or freebase, one or more times during their life']
# 1
# Currently drank alcohol
# ['at least one drink of alcohol, on at least 1 day during the 30 days before the survey']
# 1
# Had their first drink of alcohol before age 13 years
# ['other than a few sips']
# 1
# Ever took steroids without a doctor's prescription
# ['pills or shots, one or more times during their life']
# 1
# Ever used inhalants
# ['sniffed glue, breathed the contents of aerosol spray cans, or inhaled any paints or sprays to get high, one or more times during their life']
# 1
# Were offered, sold, or given an illegal drug on school property
# ['during the 12 months before the survey']
# 1
# Ever used marijuana
# ['also called grass, pot, or weed, one or more times during their life']
# 1
# Ever used heroin
# ['also called "smack," "junk," or "China White," one or more times during their life']
# 1
# Ever drank alcohol
# ['at least one drink of alcohol, on at least 1 day during their life']
# 1
# Currently used marijuana
# ['also called grass, pot, or weed, one or more times during the 30 days before the survey']
# 1
# Ever used synthetic marijuana
# ['also called "K2," "Spice," "fake weed," "King Kong," "Yucatan Fire," "Skunk," or "Moon Rocks," one or more times during their life']
# 1
# Tried marijuana for the first time before age 13 years
# ['also called grass, pot, or weed']
# 1
# Ever used methamphetamines
# ['also called "speed," "crystal," "crank," or "ice," one or more times during their life']
# 1
# Ever injected any illegal drug
# ['used a needle to inject any illegal drug into their body, one or more times during their life']
# 1
# Ever used ecstasy
# ['also called "MDMA," one or more times during their life']
# 1
# Reported 10 or more as the largest number of drinks they had in a row
# ['within a couple of hours, during the 30 days before the survey']
# 1
# Usually got the alcohol they drank by someone giving it to them
# ['during the 30 days before the survey, among students who currently drank alcohol']
# 1
# Ever took prescription pain medicine without a doctor's prescription or differently than how a doctor told them to use it
# ['counting drugs such as codeine, Vicodin, Oxycontin, Hydrocodone, and Percocet, one or more times during their life']
# 1
# Ever used hallucinogenic drugs
# ['such as LSD, acid, PCP, angel dust, mescaline, or mushrooms, one or more times during their life']
# 1
# Reported current binge drinking
# ['four or more drinks of alcohol in a row (if they were female) or five or more drinks of alcohol in a row (if they were male), within a couple of hours, on at least 1 day during the 30 days before the survey']

# %%
df.drop(columns=['Description'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55399 entries, 0 to 55398
# Data columns (total 15 columns):
# Patient_ID                  55399 non-null int64
# YEAR                        55399 non-null int64
# LocationDesc                55399 non-null object
# Subtopic                    55399 non-null int64
# Greater_Risk_Question       55399 non-null object
# Sample_Size                 55399 non-null float64
# Sex                         55399 non-null object
# Race                        55399 non-null object
# Grade                       55399 non-null int64
# QuestionCode                55399 non-null object
# StratID1                    55399 non-null int64
# StratID2                    55399 non-null int64
# StratID3                    55399 non-null int64
# StratificationType          55399 non-null object
# Greater_Risk_Probability    55399 non-null float64
# dtypes: float64(2), int64(7), object(6)
# memory usage: 6.3+ MB

# %%
### label encoding
### LocationDesc, Greater_Risk_Question, Sex, Race, QuestionCode, StratificationType
df_encoded = df.copy()

from sklearn.preprocessing import LabelEncoder
encoders = {}
for clm in ['LocationDesc', 'Greater_Risk_Question', 'Sex', 'Race', 'QuestionCode', 'StratificationType']:
    le = LabelEncoder()
    df_encoded[clm] = le.fit_transform(df_encoded[clm])
    encoders[clm] = le
df_encoded.head()
# Out:
#    Patient_ID  YEAR  LocationDesc  Subtopic  Greater_Risk_Question  \
# 0           1  1995            32         1                      6
# 1           2  1997            32         0                      0
# 2           3  1993            54         0                     14
# 3           4  2017            71         1                      6
# 4           5  2007            77         1                      5
#
#    Sample_Size  Sex  Race  Grade  QuestionCode  StratID1  StratID2  StratID3  \
# 0        335.0    0     3      4             9         1         4         0
# 1        382.0    2     2      4             2         0         3         0
# 2        196.0    0     7      0             1         1         6         2
# 3        104.0    1     1      4             9         2         2         0
# 4        100.0    0     4      4            15         1         7         0
#
#    StratificationType  Greater_Risk_Probability
# 0                   0                    7.4793
# 1                   0                   49.6852
# 2                   3                   47.8132
# 3                   3                    3.4554
# 4                   0                    0.0000

# %%
from sklearn.preprocessing import MinMaxScaler
df_scaled = df_encoded.copy()
scaler = {}
for clm in ['YEAR', 'LocationDesc', 'Subtopic', 'Greater_Risk_Question', 'Sample_Size', 'Sex', 'Race', 
            'Grade', 'QuestionCode', 'StratID1', 'StratID2', 'StratID3', 'StratificationType']:
    sc = MinMaxScaler()
    df_scaled[clm] = sc.fit_transform(df_scaled[clm].values.reshape(-1, 1))
    scaler[clm] = sc
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype int32 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype int32 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype int32 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype int32 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype int32 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype int32 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
df_scaled.head()
# Out:
#    Patient_ID      YEAR  LocationDesc  Subtopic  Greater_Risk_Question  \
# 0           1  0.153846      0.355556       1.0               0.315789
# 1           2  0.230769      0.355556       0.0               0.000000
# 2           3  0.076923      0.600000       0.0               0.736842
# 3           4  1.000000      0.788889       1.0               0.315789
# 4           5  0.615385      0.855556       1.0               0.263158
#
#    Sample_Size  Sex      Race  Grade  QuestionCode  StratID1  StratID2  \
# 0     0.005316  0.0  0.428571    1.0      0.473684       0.5  0.571429
# 1     0.006192  1.0  0.285714    1.0      0.105263       0.0  0.428571
# 2     0.002723  0.0  1.000000    0.0      0.052632       0.5  0.857143
# 3     0.001007  0.5  0.142857    1.0      0.473684       1.0  0.285714
# 4     0.000933  0.0  0.571429    1.0      0.789474       0.5  1.000000
#
#    StratID3  StratificationType  Greater_Risk_Probability
# 0       0.0                0.00                    7.4793
# 1       0.0                0.00                   49.6852
# 2       0.5                0.75                   47.8132
# 3       0.0                0.75                    3.4554
# 4       0.0                0.00                    0.0000

# %%
X = df_scaled[['YEAR', 'LocationDesc', 'Subtopic', 'Greater_Risk_Question', 'Sample_Size', 'Sex', 'Race', 
            'Grade', 'QuestionCode', 'StratID1', 'StratID2', 'StratID3', 'StratificationType']]
Y = df_scaled[['Greater_Risk_Probability']]

# %%
X.head()
# Out:
#        YEAR  LocationDesc  Subtopic  Greater_Risk_Question  Sample_Size  Sex  \
# 0  0.153846      0.355556       1.0               0.315789     0.005316  0.0
# 1  0.230769      0.355556       0.0               0.000000     0.006192  1.0
# 2  0.076923      0.600000       0.0               0.736842     0.002723  0.0
# 3  1.000000      0.788889       1.0               0.315789     0.001007  0.5
# 4  0.615385      0.855556       1.0               0.263158     0.000933  0.0
#
#        Race  Grade  QuestionCode  StratID1  StratID2  StratID3  \
# 0  0.428571    1.0      0.473684       0.5  0.571429       0.0
# 1  0.285714    1.0      0.105263       0.0  0.428571       0.0
# 2  1.000000    0.0      0.052632       0.5  0.857143       0.5
# 3  0.142857    1.0      0.473684       1.0  0.285714       0.0
# 4  0.571429    1.0      0.789474       0.5  1.000000       0.0
#
#    StratificationType
# 0                0.00
# 1                0.00
# 2                0.75
# 3                0.75
# 4                0.00

# %%
Y.head()
# Out:
#    Greater_Risk_Probability
# 0                    7.4793
# 1                   49.6852
# 2                   47.8132
# 3                    3.4554
# 4                    0.0000

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.20, random_state=42)

# %%
from sklearn.neural_network import MLPRegressor
nn = MLPRegressor()
nn
# Out:
# MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#        random_state=None, shuffle=True, solver='adam', tol=0.0001,
#        validation_fraction=0.1, verbose=False, warm_start=False)

# %%
nn.fit(X=X_train, y=y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:1316: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#        random_state=None, shuffle=True, solver='adam', tol=0.0001,
#        validation_fraction=0.1, verbose=False, warm_start=False)

# %%
print('train:', nn.score(X_train, y_train))
print('test:', nn.score(X_test, y_test))
# Out:
# train: 0.8976057289766325
# test: 0.8977704823512874

# %%
nn1 = MLPRegressor(hidden_layer_sizes=(15,30,30,15,), verbose=True, max_iter=1500)
nn1
# Out:
# MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(15, 30, 30, 15), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=1500, momentum=0.9,
#        n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#        random_state=None, shuffle=True, solver='adam', tol=0.0001,
#        validation_fraction=0.1, verbose=True, warm_start=False)

# %%
nn1.fit(X=X_train, y=y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:1316: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Iteration 1, loss =
# Iteration 271, loss = 19.99230682
# Iteration 272, loss = 19.87800078
# Iteration 273, loss = 20.02566203
# Iteration 274, loss = 19.91721366
# Iteration 275, loss = 19.75913163
# Iteration 276, loss = 19.80677666
# Iteration 277, loss = 19.89870316
# Iteration 278, loss = 19.82617821
# Iteration 279, loss = 19.80402243
# Iteration 280, loss = 19.76610916
# Iteration 281, loss = 19.97172876
# Iteration 282, loss = 19.85774324
# Iteration 283, loss = 19.75898311
# Iteration 284, loss = 19.85844792
# Iteration 285, loss = 19.72699114
# Iteration 286, loss = 19.84129659
# Iteration 287, loss = 19.72581586
# Iteration 288, loss = 19.70877658
# Iteration 289, loss = 19.83574235
# Iteration 290, loss = 19.79718058
# Iteration 291, loss = 19.69469430
# Iteration 292, loss = 19.65739591
# Iteration 293, loss = 19.78353767
# Iteration 294, loss = 19.75125307
# Iteration 295, loss = 19.69890132
# Iteration 296, loss = 19.73170018
# Iteration 297, loss = 19.64819202
# Iteration 298, loss = 19.65432064
# Iteration 299, loss = 19.64343044
# Iteration 300, loss = 19.68283862
# Iteration 301, loss = 19.74205107
# Iteration 302, loss = 19.75408089
# Iteration 303, loss = 19.69004148
# Iteration 304, loss = 19.76157568
# Iteration 305, loss = 19.64768084
# Iteration 306, loss = 19.66328078
# Iteration 307, loss = 19.61403260
# Iteration 308, loss = 19.59730719
# Iteration 309, loss = 19.70982748
# Iteration 310, loss = 19.61525176
# Iteration 311, loss = 19.50099782
# Iteration 312, loss = 19.63416953
# Iteration 313, loss = 19.63048637
# Iteration 314, loss = 19.60019454
# Iteration 315, loss = 19.58464046
# Iteration 316, loss = 19.76782932
# Iteration 317, loss = 19.57895296
# Iteration 318, loss = 19.66891403
# Iteration 319, loss = 19.50501581
# Iteration 320, loss = 19.52320642
# Iteration 321, loss = 19.56707767
# Iteration 322, loss = 19.53794932
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(15, 30, 30, 15), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=1500, momentum=0.9,
#        n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#        random_state=None, shuffle=True, solver='adam', tol=0.0001,
#        validation_fraction=0.1, verbose=True, warm_start=False)

# %%
print('train:', nn1.score(X_train, y_train))
print('test:', nn1.score(X_test, y_test))
# Out:
# train: 0.9078855153704022
# test: 0.9047711222413232

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(13, input_dim=13, activation='relu'))
model.add(Dense(1, activation='linear'))

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 13)                182
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 14
# =================================================================
# Total params: 196
# Trainable params: 196
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(X_train, y_train, epochs=5, batch_size=1)
# Out:
# Epoch 1/5
# 44319/44319 [==============================] - 31s 696us/step - loss: -371.5006 - acc: 2.2564e-05
# Epoch 2/5
# 44319/44319 [==============================] - 30s 676us/step - loss: -372.7467 - acc: 0.0000e+00
# Epoch 3/5
# 44319/44319 [==============================] - 31s 695us/step - loss: -372.7467 - acc: 0.0000e+00
# Epoch 4/5
# 44319/44319 [==============================] - 30s 671us/step - loss: -372.7467 - acc: 0.0000e+00
# Epoch 5/5
# 44319/44319 [==============================] - 31s 690us/step - loss: -372.7467 - acc: 0.0000e+00

# %%
scores = model.evaluate(X_train, y_train)
print("Train: %s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
scores = model.evaluate(X_test, y_test)
print("Train: %s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# 44319/44319 [==============================] - 1s 12us/step
# Train: acc: 0.00%
# 11080/11080 [==============================] - 0s 11us/step
# Train: acc: 0.00%

# %%
model.predict(X_train)
# Out:
# array([[2.8502254],
#        [2.0438976],
#        [2.2928386],
#        ...,
#        [2.4994478],
#        [1.7685976],
#        [2.5492425]], dtype=float32)
